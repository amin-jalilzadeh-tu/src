unified_polygon = unary_union(multipolygon)

# Check if the result is a polygon and process accordingly
if unified_polygon.geom_type == 'Polygon':
    # Extract exterior coordinates of the unified polygon
    coordinates = [(x, y) for x, y, z in unified_polygon.exterior.coords]
    print("Unified Coordinates:", coordinates)
else:
    print("The resulting geometry is not a polygon. Please check the input data.")

# Optional: For visualization or further verification
import matplotlib.pyplot as plt

def plot_polygon(polygon):
    x, y = polygon.exterior.xy
    plt.fill(x, y, alpha=0.5, fc='r', ec='black')
    plt.show()

plot_polygon(unified_polygon)
# Out:
# Unified Coordinates: [(3965558.9564138274, 304655.5518324444), (3965557.7960917894, 304654.46926552017), (3965555.782076441, 304654.31453854137), (3965553.3883239017, 304658.37312426727), (3965562.039773763, 304666.4245654954), (3965562.22025118, 304666.4384312246), (3965562.233945192, 304666.45073700097), (3965564.192742306, 304666.6012275819), (3965565.721556598, 304664.06130098924), (3965567.5910079125, 304664.20492605306), (3965568.03881575, 304663.45795529813), (3965569.125092809, 304663.54141091456), (3965571.5291484445, 304659.5149530315), (3965567.206319343, 304655.46573235287), (3965566.5870983754, 304655.4181605826), (3965564.0258357706, 304652.9301203356), (3965560.6412189854, 304652.67009845364), (3965560.29304895, 304653.2806989866), (3965558.9564138274, 304655.5518324444)]

# %%
# Function to calculate height differences
def calculate_height_differences(polygon):
    if polygon.geom_type == 'Polygon':
        z_values = [z for x, y, z in polygon.exterior.coords]
        return max(z_values) - min(z_values)  # Height difference
    return None

# Calculate height differences for each polygon in the multipolygon
height_differences = [calculate_height_differences(poly) for poly in multipolygon.geoms]
print("Height Differences for Each Polygon:", height_differences)
# Out:
# Height Differences for Each Polygon: [11.360256562940776, 6.519606336951256, 5.489073195494711, 2.8689820896834135, 3.908904221840203, 1.9134430950507522, 8.58587012719363, 4.681510400958359, 5.423117679543793, 5.342146043665707, 4.13237558491528, 6.545676230452955, 2.510227408260107, 2.587000668980181, 9.829718478024006, 3.5050841439515352, 4.086964068934321, 4.506535060703754, 3.841505347751081, 5.787480372004211, 8.510992405936122, 4.588798077777028]

# %%
from shapely.wkt import loads
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
from shapely.wkt import loads
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Original WKT data with the added closure point at the end
wkt_data = "MULTIPOLYGON Z (((137584.296875 370485.5625 27.66200065612793,137584.828125 370486 27.66200065612793,137585.28125 370486 27.66200065612793,137585.828125 370485.875 27.66200065612793,137584.296875 370485.5625 27.66200065612793)))"

# Load the WKT data into a Shapely geometry
try:
    multipolygon_z = loads(wkt_data)
except Exception as e:
    print(f"Error loading WKT: {e}")

# Plotting setup for 3D visualization
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Iterate through all polygons in the multipolygon
for polygon in multipolygon_z.geoms:
    exterior_coords = polygon.exterior.coords
    x, y, z = zip(*exterior_coords)  # Unzip into x, y, z coordinate lists

    # Create a list of vertices for the 3D polygon
    verts = [list(zip(x, y, z))]

    # Create a 3D polygon collection
    poly3d = Poly3DCollection(verts, alpha=0.5, facecolor='cyan', edgecolor='black')
    ax.add_collection3d(poly3d)

    # Set the plot limits to fit the largest coordinates
    ax.set_xlim(min(x), max(x))
    ax.set_ylim(min(y), max(y))
    ax.set_zlim(min(z), max(z))

ax.set_xlabel('X Coordinates')
ax.set_ylabel('Y Coordinates')
ax.set_zlabel('Height (Z)')

plt.show()
# Out:
# D:\Drives\Temp\ipykernel_2220\231493569.py:33: UserWarning: Attempting to set identical bottom == top == 27.66200065612793 results in singular transformations; automatically expanding.
#   ax.set_zlim(min(z), max(z))
